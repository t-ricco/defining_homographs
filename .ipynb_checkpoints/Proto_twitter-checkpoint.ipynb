# %%
import tweepy
import cnfg

config = cnfg.load(".twitter_config")

"""oauth = OAuth1(config["consumer_key"],
               config["consumer_secret"],
               config["access_token"],
               config["access_token_secret"])"""
# Out:
# 'oauth = OAuth1(config["consumer_key"],\n               config["consumer_secret"],\n               config["access_token"],\n               config["access_token_secret"])'

# %%
# Replace the API_KEY and API_SECRET with your application's key and secret.
auth = tweepy.AppAuthHandler(config["consumer_key"], config["consumer_secret"])

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)

# Continue with rest of code

# %%
! pip install jsonpickle
# Out:
# ...
#     100% |████████████████████████████████| 71kB 642kB/s ta 0:00:011
# ...
#   Running setup.py bdist_wheel for jsonpickle ... done
#   Stored in directory: /Users/Tom/Library/Caches/pip/wheels/81/6f/c9/7c9b890ed6c83a02e2619330930fc1962ebab44cbad8cec52b
# Successfully built jsonpickle
# ...

# %%
import sys
import jsonpickle
import os

searchQuery = 'repjoegarcia'  # this is what we're searching for
maxTweets = 10000000 # Some arbitrary large number
tweetsPerQry = 100  # this is the max the API permits
fName = 'tweets.txt' # We'll store the tweets in a text file.


# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = -1L

tweetCount = 0
print("Downloading max {0} tweets".format(maxTweets))
with open(fName, 'w') as f:
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry)
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            since_id=sinceId)
            else:
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1))
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId)
            if not new_tweets:
                print("No more tweets found")
                break
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json, unpicklable=False) +
                        '\n')
            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets".format(tweetCount))
            max_id = new_tweets[-1].id
        except tweepy.TweepError as e:
            # Just exit if any error
            print("some error : " + str(e))
            break

print ("Downloaded {0} tweets, Saved to {1}".format(tweetCount, fName))
# Out:
# ...
# Downloaded 1 tweets
# No more tweets found
# Downloaded 1 tweets, Saved to tweets.txt

# %%
import pandas as pd

head = open('tweets.txt','rb')
tweet = jsonpickle.decode(head.readline())
tweets = pd.DataFrame(data = tweet.values(),columns = tweet.keys())


#for line in head:
#    tweet = pd.DataFrame(jsonpickle.decode(line))
#    tweets.append(pd.DataFrame(tweet))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-7ea549cd9c2b> in <module>()
#       3 head = open('tweets.txt','rb')
#       4 tweet = jsonpickle.decode(head.readline())
# ----> 5 tweets = pd.DataFrame(data = tweet.values(),columns = tweet.keys())
#       6
#       7
#
# /Users/Tom/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     328                 else:
#     329                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 330                                              copy=copy)
#     331             else:
#     332                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#
# /Users/Tom/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_ndarray(self, values, index, columns, dtype, copy)
# ...

# %%
tweets.head()
# Out:
#                       contributors coordinates  \
# contributors_enabled          None        None
# created_at                    None        None
# default_profile               None        None
# default_profile_image         None        None
# description                   None        None
#
#                                            created_at entities  \
# contributors_enabled   Sat Aug 19 00:00:21 +0000 2017      NaN
# created_at             Sat Aug 19 00:00:21 +0000 2017      NaN
# default_profile        Sat Aug 19 00:00:21 +0000 2017      NaN
# default_profile_image  Sat Aug 19 00:00:21 +0000 2017      NaN
# description            Sat Aug 19 00:00:21 +0000 2017      NaN
#
#                        favorite_count  favorited   geo                  id  \
# contributors_enabled                0      False  None  898696100013633536
# created_at                          0      False  None  898696100013633536
# ...

# %%
for t in tweets.text:
    print t
# Out:
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# My week on Twitter 🎉: 1 Tweet. See yours with https://t.co/mgXu2QoeGP
# ...
